# %% [markdown]
# #### 1)

# %%
import pandas as pd

# %%
df = pd.read_excel('board2.xlsx')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
df['Average'] = (df['Math'] + df['Electronics'] + df['GEAS'] + df['Communication']) / 4
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
f = df.describe()
f
# Out:
#             Math  Electronics       GEAS  Communication    Average
# count  30.000000     30.00000  30.000000      30.000000  30.000000
# mean   72.166667     61.60000  71.866667      61.966667  66.900000
# std    12.660237     17.29381  15.725519      15.376837   7.322792
# min    48.000000     35.00000  40.000000      41.000000  47.750000
# 25%    64.250000     47.00000  61.250000      49.000000  62.312500
# 50%    73.500000     60.00000  76.000000      60.000000  67.500000
# 75%    83.000000     76.50000  83.750000      72.750000  72.187500
# max    89.000000     91.00000  94.000000      88.000000  80.500000

# %%
 f.mean()
# Out:
# Math             59.072113
# Electronics      52.299226
# GEAS             59.074023
# Communication    52.261688
# Average          54.309099
# dtype: float64

# %%
Instru = df.loc[(df['Hometown']=='Luzon')&(df['Track']=='Instrumentation')&(df['Electronics']>70), ['Name', 'GEAS', 'Electronics']]
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %%
s = df.loc[(df['Hometown']=='Mindanao')&(df['Gender']=='Female')]
s
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 19  S20  Female     Communication  Mindanao    59           60    62
#
#     Communication  Average
# 1              52    67.25
# 2              57    72.75
# 14             86    59.00
# 16             45    70.50
# 19             85    66.50

# %%
# a)
w = df.loc[(df['Hometown']=='Mindanao')&(df['Gender']=='Female'), ['Name','Math', 'Electronics', 'GEAS', 'Communication']]
w
# Out:
#    Name  Math  Electronics  GEAS  Communication
# 1    S2    52           75    90             52
# 2    S3    83           74    77             57
# 14  S15    69           41    40             86
# 16  S17    81           79    77             45
# 19  S20    59           60    62             85

# %%
a=s.describe()
a
# Out:
#             Math  Electronics      GEAS  Communication   Average
# count   5.000000     5.000000   5.00000       5.000000   5.00000
# mean   68.800000    65.800000  69.20000      65.000000  67.20000
# std    13.498148    15.610894  19.09712      19.196354   5.23032
# min    52.000000    41.000000  40.00000      45.000000  59.00000
# 25%    59.000000    60.000000  62.00000      52.000000  66.50000
# 50%    69.000000    74.000000  77.00000      57.000000  67.25000
# 75%    81.000000    75.000000  77.00000      85.000000  70.50000
# max    83.000000    79.000000  90.00000      86.000000  72.75000

# %%
s['Average'] = (s['Math'] + s['Electronics'] + s['GEAS'] + s['Communication']) / 4
s
# Out:
# C:\Users\Mycho\AppData\Local\Temp\ipykernel_6196\4117810910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['Average'] = (s['Math'] + s['Electronics'] + s['GEAS'] + s['Communication']) / 4
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 19  S20  Female     Communication  Mindanao    59           60    62
#
#     Communication  Average
# 1              52    67.25
# 2              57    72.75
# 14             86    59.00
# ...

# %%
s
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 19  S20  Female     Communication  Mindanao    59           60    62
#
#     Communication  Average
# 1              52    67.25
# 2              57    72.75
# 14             86    59.00
# 16             45    70.50
# 19             85    66.50

# %%
# b)
Mindy = s.loc[s['Average'] >= 55, ['Name', 'Track', 'Electronics', 'Average']]
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %% [markdown]
# #### 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (18,10))
plt.bar(df['Name'], df['Average'])
# Out:
# <BarContainer object of 30 artists>

# %%
plt.figure(figsize = (30, 20))
df.plot.bar(x='Name', y=['Math', 'GEAS', 'Electronics', 'Communication'])
# Out:
# <Axes: xlabel='Name'>
